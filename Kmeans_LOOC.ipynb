# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn import metrics
from numpy import load
from keras.utils import to_categorical
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping
from sklearn.cluster import Birch
le = preprocessing.LabelEncoder()
import scikitplot as skplt

# %%
url = 'C:/Users/iqbal/Desktop/CogWear/'

# %%
Y_list = ['baseline_Y_0.npy', 'baseline_Y_1.npy', 'baseline_Y_2.npy', 'baseline_Y_4.npy', 'baseline_Y_5.npy',
              'baseline_Y_6.npy', 'baseline_Y_7.npy', 'baseline_Y_8.npy', 'baseline_Y_9.npy', 'baseline_Y_10.npy',
              'cognitive_load_Y_0.npy', 'cognitive_load_Y_1.npy', 'cognitive_load_Y_2.npy', 'cognitive_load_Y_4.npy', 'cognitive_load_Y_5.npy',
              'cognitive_load_Y_6.npy', 'cognitive_load_Y_7.npy', 'cognitive_load_Y_8.npy', 'cognitive_load_Y_9.npy', 'cognitive_load_Y_10.npy']

# %%
y = load(url + Y_list[0])

for i in range(len(Y_list) - 1):
    data = load(url + Y_list[i + 1])
    y = np.append(y, data, axis = 0)

# %%
X = load(url + 'features_64_10_30.npy')

# %%
X.shape

# %%
X = preprocessing.normalize(X)

# %%
y.shape

# %%
y

# %%
y = np.select([y == 'baseline', y == 'cognitive_load'], [0, 1], y)

# %%
Y = to_categorical(y)

# %%
yt = le.fit_transform(y)

# %%
y = yt

# %%
y.shape

# %%
y

# %%
print('0_b_size: ' + str(load(url + Y_list[0]).shape))
print('0_c_size: ' + str(load(url + Y_list[10]).shape))
print('1_b_size: ' + str(load(url + Y_list[1]).shape))
print('1_c_size: ' + str(load(url + Y_list[11]).shape))
print('2_b_size: ' + str(load(url + Y_list[2]).shape))
print('2_c_size: ' + str(load(url + Y_list[12]).shape))
print('4_b_size: ' + str(load(url + Y_list[3]).shape))
print('4_c_size: ' + str(load(url + Y_list[13]).shape))
print('5_b_size: ' + str(load(url + Y_list[4]).shape))
print('5_c_size: ' + str(load(url + Y_list[14]).shape))
print('6_b_size: ' + str(load(url + Y_list[5]).shape))
print('6_c_size: ' + str(load(url + Y_list[15]).shape))
print('7_b_size: ' + str(load(url + Y_list[6]).shape))
print('7_c_size: ' + str(load(url + Y_list[16]).shape))
print('8_b_size: ' + str(load(url + Y_list[7]).shape))
print('8_c_size: ' + str(load(url + Y_list[17]).shape))
print('9_b_size: ' + str(load(url + Y_list[8]).shape))
print('9_c_size: ' + str(load(url + Y_list[18]).shape))
print('10_b_size: ' + str(load(url + Y_list[9]).shape))
print('10_c_size: ' + str(load(url + Y_list[19]).shape))

# %%
participant_0_X = np.append(X[0 : 112], X[910 : 1076], axis=0)
participant_0_y = np.append(y[0 : 112], y[910 : 1076], axis=0)
participant_1_X = np.append(X[112 : 227], X[1076 : 1206], axis=0)
participant_1_y = np.append(y[112 : 227], y[1076 : 1206], axis=0)
participant_2_X = np.append(X[227 : 336], X[1206 : 1482], axis=0)
participant_2_y = np.append(y[227 : 336], y[1206 : 1482], axis=0)
participant_4_X = np.append(X[336 : 445], X[1482 : 1587], axis=0)
participant_4_y = np.append(y[336 : 445], y[1482 : 1587], axis=0)
participant_5_X = np.append(X[445 : 493], X[1587 : 1643], axis=0)
participant_5_y = np.append(y[445 : 493], y[1587 : 1643], axis=0)
participant_6_X = np.append(X[493 : 566], X[1643 : 1705], axis=0)
participant_6_y = np.append(y[493 : 566], y[1643 : 1705], axis=0)
participant_7_X = np.append(X[566 : 665], X[1705 : 1851], axis=0)
participant_7_y = np.append(y[566 : 665], y[1705 : 1851], axis=0)
participant_8_X = np.append(X[665 : 811], X[1851 : 1958], axis=0)
participant_8_y = np.append(y[665 : 811], y[1851 : 1958], axis=0)
participant_9_X = np.append(X[811 : 860], X[1958 : 2187], axis=0)
participant_9_y = np.append(y[811 : 860], y[1958 : 2187], axis=0)
participant_10_X = np.append(X[860 : 910], X[2187 : 2285], axis=0)
participant_10_y = np.append(y[860 : 910], y[2187 : 2285], axis=0)

# %%
fold_1_trainX = np.concatenate((participant_0_X, participant_1_X, participant_2_X,
                                participant_4_X, participant_5_X, participant_6_X,
                                participant_7_X, participant_8_X, participant_9_X), axis=0)
fold_1_trainY = np.concatenate((participant_0_y, participant_1_y, participant_2_y,
                                participant_4_y, participant_5_y, participant_6_y,
                                participant_7_y, participant_8_y, participant_9_y), axis=0)
fold_1_testX = participant_10_X
fold_1_testY = participant_10_y

# %%
fold_2_trainX = np.concatenate((participant_0_X, participant_1_X, participant_2_X,
                                participant_4_X, participant_5_X, participant_6_X,
                                participant_7_X, participant_8_X, participant_10_X), axis=0)
fold_2_trainY = np.concatenate((participant_0_y, participant_1_y, participant_2_y,
                                participant_4_y, participant_5_y, participant_6_y,
                                participant_7_y, participant_8_y, participant_10_y), axis=0)
fold_2_testX = participant_9_X
fold_2_testY = participant_9_y

# %%
fold_3_trainX = np.concatenate((participant_0_X, participant_1_X, participant_2_X,
                                participant_4_X, participant_5_X, participant_6_X,
                                participant_7_X, participant_10_X, participant_9_X), axis=0)
fold_3_trainY = np.concatenate((participant_0_y, participant_1_y, participant_2_y,
                                participant_4_y, participant_5_y, participant_6_y,
                                participant_7_y, participant_10_y, participant_9_y), axis=0)
fold_3_testX = participant_8_X
fold_3_testY = participant_8_y

# %%
fold_4_trainX = np.concatenate((participant_0_X, participant_1_X, participant_2_X,
                                participant_4_X, participant_5_X, participant_6_X,
                                participant_10_X, participant_8_X, participant_9_X), axis=0)
fold_4_trainY = np.concatenate((participant_0_y, participant_1_y, participant_2_y,
                                participant_4_y, participant_5_y, participant_6_y,
                                participant_10_y, participant_8_y, participant_9_y), axis=0)
fold_4_testX = participant_7_X
fold_4_testY = participant_7_y

# %%
fold_5_trainX = np.concatenate((participant_0_X, participant_1_X, participant_2_X,
                                participant_4_X, participant_5_X, participant_10_X,
                                participant_7_X, participant_8_X, participant_9_X), axis=0)
fold_5_trainY = np.concatenate((participant_0_y, participant_1_y, participant_2_y,
                                participant_4_y, participant_5_y, participant_10_y,
                                participant_7_y, participant_8_y, participant_9_y), axis=0)
fold_5_testX = participant_6_X
fold_5_testY = participant_6_y

# %%
fold_6_trainX = np.concatenate((participant_0_X, participant_1_X, participant_2_X,
                                participant_4_X, participant_10_X, participant_6_X,
                                participant_7_X, participant_8_X, participant_9_X), axis=0)
fold_6_trainY = np.concatenate((participant_0_y, participant_1_y, participant_2_y,
                                participant_4_y, participant_10_y, participant_6_y,
                                participant_7_y, participant_8_y, participant_9_y), axis=0)
fold_6_testX = participant_5_X
fold_6_testY = participant_5_y

# %%
fold_7_trainX = np.concatenate((participant_0_X, participant_1_X, participant_2_X,
                                participant_10_X, participant_5_X, participant_6_X,
                                participant_7_X, participant_8_X, participant_9_X), axis=0)
fold_7_trainY = np.concatenate((participant_0_y, participant_1_y, participant_2_y,
                                participant_10_y, participant_5_y, participant_6_y,
                                participant_7_y, participant_8_y, participant_9_y), axis=0)
fold_7_testX = participant_4_X
fold_7_testY = participant_4_y

# %%
fold_8_trainX = np.concatenate((participant_0_X, participant_1_X, participant_10_X,
                                participant_4_X, participant_5_X, participant_6_X,
                                participant_7_X, participant_8_X, participant_9_X), axis=0)
fold_8_trainY = np.concatenate((participant_0_y, participant_1_y, participant_10_y,
                                participant_4_y, participant_5_y, participant_6_y,
                                participant_7_y, participant_8_y, participant_9_y), axis=0)
fold_8_testX = participant_2_X
fold_8_testY = participant_2_y

# %%
fold_9_trainX = np.concatenate((participant_0_X, participant_10_X, participant_2_X,
                                participant_4_X, participant_5_X, participant_6_X,
                                participant_7_X, participant_8_X, participant_9_X), axis=0)
fold_9_trainY = np.concatenate((participant_0_y, participant_10_y, participant_2_y,
                                participant_4_y, participant_5_y, participant_6_y,
                                participant_7_y, participant_8_y, participant_9_y), axis=0)
fold_9_testX = participant_1_X
fold_9_testY = participant_1_y

# %%
fold_10_trainX = np.concatenate((participant_10_X, participant_1_X, participant_2_X,
                                participant_4_X, participant_5_X, participant_6_X,
                                participant_7_X, participant_8_X, participant_9_X), axis=0)
fold_10_trainY = np.concatenate((participant_10_y, participant_1_y, participant_2_y,
                                participant_4_y, participant_5_y, participant_6_y,
                                participant_7_y, participant_8_y, participant_9_y), axis=0)
fold_10_testX = participant_0_X
fold_10_testY = participant_0_y

# %%
precision = []
recall = []
f1 = []
accuracy = []
homogeneity = []
completeness = []
vmeasure = []
ar = []
am =[]
sc = []
inertia = []

# %% [markdown]
# # FOLD 1

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_1_trainX)

# %%
y_pred = kmeans.predict(fold_1_testX)

# %%
yt = fold_1_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_1_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_1_testX, y_pred)

# %% [markdown]
# # FOLD 2

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_2_trainX)

# %%
y_pred = kmeans.predict(fold_2_testX)

# %%
y_pred_t = 1 - y_pred

# %%
y_pred = y_pred_t

# %%
yt = fold_2_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_2_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_2_testX, y_pred)

# %% [markdown]
# # FOLD 3

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_3_trainX)

# %%
y_pred = kmeans.predict(fold_3_testX)

# %%
yt = fold_3_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_3_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_3_testX, y_pred)

# %% [markdown]
# # FOLD 4

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_4_trainX)

# %%
y_pred = kmeans.predict(fold_4_testX)

# %%
y_pred_t = 1 - y_pred

# %%
y_pred = y_pred_t

# %%
yt = fold_4_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_4_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_4_testX, y_pred)

# %% [markdown]
# # FOLD 5

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_5_trainX)

# %%
y_pred = kmeans.predict(fold_5_testX)

# %%
yt = fold_5_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_5_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_5_testX, y_pred)

# %% [markdown]
# # FOLD 6

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_6_trainX)

# %%
y_pred = kmeans.predict(fold_6_testX)

# %%
yt = fold_6_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_6_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_6_testX, y_pred)

# %% [markdown]
# # FOLD 7

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_7_trainX)

# %%
y_pred = kmeans.predict(fold_7_testX)

# %%
yt = fold_7_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_7_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_7_testX, y_pred)

# %% [markdown]
# # FOLD 8

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_8_trainX)

# %%
y_pred = kmeans.predict(fold_8_testX)

# %%
yt = fold_8_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_8_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_8_testX, y_pred)

# %% [markdown]
# # FOLD 9

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_9_trainX)

# %%
y_pred = kmeans.predict(fold_9_testX)

# %%
y_pred_t = 1 - y_pred

# %%
y_pred = y_pred_t

# %%
yt = fold_9_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_9_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_9_testX, y_pred)

# %% [markdown]
# # FOLD 10

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
clusters_kmean = kmeans.fit(fold_10_trainX)

# %%
y_pred = kmeans.predict(fold_10_testX)

# %%
yt = fold_10_testY
accuracy.append(metrics.accuracy_score(yt, y_pred))
precision.append(metrics.precision_score(yt, y_pred))
recall.append(metrics.recall_score(yt, y_pred))
f1.append(metrics.f1_score(yt, y_pred))
homogeneity.append(metrics.homogeneity_score(yt, y_pred))
completeness.append(metrics.completeness_score(yt, y_pred))
vmeasure.append(metrics.v_measure_score(yt, y_pred))
ar.append(metrics.adjusted_rand_score(yt, y_pred))
am.append(metrics.adjusted_mutual_info_score(yt, y_pred))
sc.append(metrics.silhouette_score(fold_10_testX, y_pred))
inertia.append(kmeans.inertia_)
skplt.metrics.plot_silhouette(fold_10_testX, y_pred)

# %% [markdown]
# # LEAVE ONE GROUPT OUT CROSS VALIDATION FINAL RESULT

# %%
result = pd.DataFrame(['FOLD 1', 'FOLD 2', 'FOLD 3', 'FOLD 4', 'FOLD 5',
                       'FOLD 6', 'FOLD 7', 'FOLD 8', 'FOLD 9', 'FOLD 10'], columns=['HEADINGS'])

# %%
result['PRECISION'] = precision
result['RECALL'] = recall
result['F1'] = f1
result['ACCURACY'] = accuracy
result['HOMOGENEITY'] = homogeneity
result['COMPLETENESS'] = completeness
result['V-MEASURE'] = vmeasure
result['ADJUSTED RAND INDEX'] = ar
result['ADJUSTED MUTUAL INFORMATION'] = am
result['SILHOUETTE COEFICIENT'] = sc
result['INERTIA'] = inertia

# %%
result

# %%
result.loc[len(result.index)] = ['MEAN', result['PRECISION'].mean(), result['RECALL'].mean(), result['F1'].mean(), result['ACCURACY'].mean(),
                                 result['HOMOGENEITY'].mean(), result['COMPLETENESS'].mean(), result['V-MEASURE'].mean(),
                                 result['ADJUSTED RAND INDEX'].mean(), result['ADJUSTED MUTUAL INFORMATION'].mean(),
                                 result['SILHOUETTE COEFICIENT'].mean(), result['INERTIA'].mean()]

# %%
result.loc[len(result.index)] = ['STD', result['PRECISION'].std(), result['RECALL'].std(), result['F1'].std(), result['ACCURACY'].std(),
                                 result['HOMOGENEITY'].std(), result['COMPLETENESS'].std(), result['V-MEASURE'].std(),
                                 result['ADJUSTED RAND INDEX'].std(), result['ADJUSTED MUTUAL INFORMATION'].std(),
                                 result['SILHOUETTE COEFICIENT'].std(), result['INERTIA'].std()]

# %%
result

# %%
result['PRECISION'] = result['PRECISION'].apply(lambda x: float("{:.4f}".format(x)))
result['RECALL'] = result['RECALL'].apply(lambda x: float("{:.4f}".format(x)))
result['F1'] = result['F1'].apply(lambda x: float("{:.4f}".format(x)))
result['ACCURACY'] = result['ACCURACY'].apply(lambda x: float("{:.4f}".format(x)))
result['HOMOGENEITY'] = result['HOMOGENEITY'].apply(lambda x: float("{:.2f}".format(x)))
result['COMPLETENESS'] = result['COMPLETENESS'].apply(lambda x: float("{:.2f}".format(x)))
result['V-MEASURE'] = result['V-MEASURE'].apply(lambda x: float("{:.2f}".format(x)))
result['ADJUSTED RAND INDEX'] = result['ADJUSTED RAND INDEX'].apply(lambda x: float("{:.2f}".format(x)))
result['ADJUSTED MUTUAL INFORMATION'] = result['ADJUSTED MUTUAL INFORMATION'].apply(lambda x: float("{:.2f}".format(x)))
result['SILHOUETTE COEFICIENT'] = result['SILHOUETTE COEFICIENT'].apply(lambda x: float("{:.2f}".format(x)))
result['INERTIA'] = result['INERTIA'].apply(lambda x: float("{:.2f}".format(x)))

# %%
result

# %%
result['PRECISION'] = result['PRECISION'] * 100
result['RECALL'] = result['RECALL'] * 100
result['F1'] = result['F1'] * 100
result['ACCURACY'] = result['ACCURACY'] * 100

# %%
result

# %%
result.to_csv(url + 'KMEANS_LOOC_RESULT_PILOT.csv', index=False)
